# %%
from linescanning import simulate, plotting
import yaml
import numpy as np

# %%
#---------------------------------------------------------------------------------------------------
# EXPERIMENT SETTINGS
settings_path = "/data1/projects/MicroFunc/Jurjen/programs/project_repos/Experiments/BlockFingertap/settings.yml"
with open(settings_path, 'r', encoding='utf8') as f_in:
    settings = yaml.safe_load(f_in)

events = ["right","left","both"]
n_events = len(events)
stim_repetitions = settings['design'].get('n_repeats')
n_trials = int(n_events*stim_repetitions)

itis2 = simulate.ITI(
    tmin=settings['design'].get('minimal_iti_duration'),
    tmax=settings['design'].get('maximal_iti_duration'),
    tmean=settings['design'].get('mean_iti_duration'),    
    n_trials=n_trials,
    leeway=settings['design'].get('total_iti_duration_leeway'),
    stim_duration=settings['design'].get('stim_duration'),
    total_duration=settings['design'].get('intended_duration'),
    start_duration=settings['design'].get('start_duration'),
    end_duration=settings['design'].get('end_duration'),
    events=events,
    verbose=True
)

# %matplotlib inline
itis2.plot_iti_distribution()
# np.savetxt(f"/data1/projects/MicroFunc/Jurjen/programs/project_repos/Experiments/BlockFingertap/itis_desc-{n_trials}_events.txt", itis.itis)
# Out:
# ITIs created with total ITI duration of 216.36s after 0 iterations
# Total experiment time: 330.36s (= 3146 samples)

# %%
itis2.onset_df.reset_index()["event_type"].factorize()[0]
# Out:
# array([0, 1, 2, 1, 1, 0, 2, 2, 0, 2, 2, 1, 0, 0, 2, 1, 1, 0])

# %%
np.savetxt(f"/data1/projects/MicroFunc/Jurjen/programs/project_repos/Experiments/BlockFingertap/itis_desc-{n_trials}_events.txt", itis2.itis)
np.savetxt(f"/data1/projects/MicroFunc/Jurjen/programs/project_repos/Experiments/BlockFingertap/itis_desc-{n_trials}_order.txt", itis2.onset_df.reset_index()["event_type"].factorize()[0])

# %%
itis = simulate.ITI(
    tmin=settings['design'].get('minimal_iti_duration'),
    tmax=settings['design'].get('maximal_iti_duration'),
    tmean=settings['design'].get('mean_iti_duration'),    
    n_trials=n_trials,
    leeway=settings['design'].get('total_iti_duration_leeway'),
    stim_duration=settings['design'].get('stim_duration'),
    total_duration=settings['design'].get('intended_duration'),
    start_duration=settings['design'].get('start_duration'),
    end_duration=settings['design'].get('end_duration'),
    events=events,
    verbose=True
)

# %matplotlib inline
itis.plot_iti_distribution()
np.savetxt(f"/data1/projects/MicroFunc/Jurjen/programs/project_repos/Experiments/BlockFingertap/itis_desc-{n_trials}_events.txt", itis.itis)
# Out:
# ITIs created with total ITI duration of 209.67s after 18 iterations
# Total experiment time: 332.67s (= 3168 samples)
